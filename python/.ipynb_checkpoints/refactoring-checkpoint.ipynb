# %%
import cv2 as cv
import numpy as np
import json
import os

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
def read_points_3d(name):
    file = open(f"../c++/{name}")
    data = json.load(file)
    res = np.reshape(data["points_3d"], (-1, 3))
    return res

# %%
# %matplotlib notebook

points = []
# for i in range(10):
#     points.append(read_points_3d(f"points-3d_pairs/{i}-{i+1}.json"))

points.append(read_points_3d(f"points-3d/norm.json"))

# Create a figure and a 3D axis
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = []
y = []
z = []

for pts in points[7:8]:
    for x_pt, y_pt, z_pt in pts:
        if (-150 < x_pt <100) and (-150 < y_pt <100) and (-150 < z_pt <100):
            x.append(x_pt)
            y.append(y_pt)
            z.append(z_pt)

x = np.array(x)
y = np.array(y)
z = np.array(z)

print(len(x))

# Create a 3D scatter plot
ax.scatter(x, y, z, c=z, marker='o', s=8)



# Set the title
ax.set_title('Interactive 3D Plot')

# Show the plot
plt.show()
# Out:
# [[-1.65262079 -1.01222944  3.25139046]
#  [-1.6400311  -0.48204935  3.23804331]
#  [-1.63633299 -0.8284896   3.25075531]
#  ...
#  [ 5.87972879 -3.5477767  15.8136253 ]
#  [ 5.87972879 -3.5477767  15.8136253 ]
#  [ 5.9793849  -3.77359056 15.963419  ]]
# <img src="data:image/png;base64,..." width="640">
# 442
